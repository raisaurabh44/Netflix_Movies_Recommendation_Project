# %% [markdown]
# <a href="https://colab.research.google.com/github/raisaurabh44/Netflix_Movies_Recommendation_Project/blob/main/Netflix_Movies_Recommendation_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Netflix prize dataset
#importing the necessary libraries for importing the dataset in jupyter notebook
#Around100M+ ratings 4499 movies 480,000 users
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading data
netflix_dataset= pd.read_csv('/content/drive/MyDrive/Netflix_movies_recomendation_Project/combined_data_1.txt', header=None, names=['Cust_Id','Rating'], usecols = [0,1])
netflix_dataset
# Out:
#          Cust_Id  Rating
# 0             1:     NaN
# 1        1488844     3.0
# 2         822109     5.0
# 3         885013     4.0
# 4          30878     4.0
# ...          ...     ...
# 2446064  1475817     4.0
# 2446065  2140917     5.0
# 2446066   172630     4.0
# 2446067  1184829     3.0
# 2446068   235691     4.0
#
# [2446069 rows x 2 columns]

# %%
movies_count=netflix_dataset.isnull().sum()
movies_count=movies_count['Rating']

# %%
movies_count
# Out:
# 457

# %%
netflix_dataset.isna().sum()
# Out:
# Cust_Id      0
# Rating     457
# dtype: int64
